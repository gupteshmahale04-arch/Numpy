# %% [markdown]
# <a href="https://colab.research.google.com/github/gupteshmahale04-arch/Numpy/blob/main/Numpy_4_Assign_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # NumPy Assignment — Fancy Indexing, Conditional Selection, Sorting & Stacking
#
# ## Level: Basic
#
# ### Topics Covered
# - Fancy Indexing
# - Conditional Selection
# - np.sort()
# - np.argsort()
# - Concatenation
# - Vertical Stacking
# - Horizontal Stacking
#
# ### Instructions
# - Use NumPy in every question.
# - Write your solution in the code cell below each question.
# - Print the required output.

# %% [markdown]
# # Q1. Fancy Indexing (1D Array)
#
# ## Problem Statement
# Create the array:
#
# ```python
# [10, 20, 30, 40, 50, 60]
# ```
#
# Using fancy indexing, print:
# - 10
# - 30
# - 60
#
# ## Sample Output
# ```python
# [10 30 60]
# ```

# %%
# Write your code here
import numpy as np
arr=np.array([10,20,30,40,50,60])
print(arr[[0,2,5]])
# Out:
# [10 30 60]

# %%
import numpy as np
arr=np.array([10,20,30,40,50,60])
print(arr[[0,2,5]])
# Out:
# [10 30 60]

# %% [markdown]
# # Q2. Fancy Indexing (1D Array)
#
# ## Problem Statement
# Create the array:
#
# ```python
# [5, 15, 25, 35, 45]
# ```
#
# Using fancy indexing, print:
# - 15
# - 45
#
# ## Sample Output
# ```python
# [15 45]
# ```

# %%
# Write your code here
import numpy as np
arr=np.array([5, 15, 25, 35, 45])
print(arr[[1,4]])
# Out:
# [15 45]

# %% [markdown]
# # Q3. Fancy Indexing (2D Array)
#
# ## Problem Statement
# Create the matrix:
#
# ```python
# [[10,20,30],
#  [40,50,60],
#  [70,80,90]]
# ```
#
# Using fancy indexing, print:
# - 10
# - 50
# - 90
#
# ## Sample Output
# ```python
# [10 50 90]
# ```

# %%
# Write your code here
import numpy as np
arr=np.array([[10,20,30], [40,50,60],[70,80,90]])
print(arr[[0,1,2],[0,1,2]])
# Out:
# [10 50 90]

# %% [markdown]
# # Q4. Conditional Selection
#
# ## Problem Statement
# Create the array:
#
# ```python
# [5, 12, 18, 25, 30, 7]
# ```
#
# Print only values greater than 15.
#
# ## Sample Output
# ```python
# [18 25 30]
# ```

# %%
# Write your code here
import numpy as np
arr=np.array([5, 12, 18, 25, 30, 7])
print(arr[arr>15])
# Out:
# [18 25 30]

# %% [markdown]
# # Q5. Conditional Selection
#
# ## Problem Statement
# Create the array:
#
# ```python
# [2, 4, 7, 10, 13, 16]
# ```
#
# Print only even numbers.
#
# ## Sample Output
# ```python
# [ 2  4 10 16]
# ```

# %%
# Write your code here
import numpy as np
arr=np.array([2, 4, 7, 10, 13, 16])
print(arr[arr%2==0])
# Out:
# [ 2  4 10 16]

# %% [markdown]
# # Q6. Sorting an Array
#
# ## Problem Statement
# Create the array:
#
# ```python
# [25, 10, 40, 5, 30]
# ```
#
# Sort the array using `np.sort()`.
#
# ## Sample Output
# ```python
# [ 5 10 25 30 40]
# ```

# %%
# Write your code hereimport numpy as np
arr=np.array([25, 10, 40, 5, 30])
print (np.sort(arr))
# Out:
# [ 5 10 25 30 40]

# %% [markdown]
# # Q7. Find Sorted Indices
#
# ## Problem Statement
# Create the array:
#
# ```python
# [50, 20, 70, 10]
# ```
#
# Use `np.argsort()` to find the indices of sorted elements.
#
# ## Sample Output
# ```python
# [3 1 0 2]
# ```

# %%
# Write your code here
arr=np.array([50, 20, 70, 10])
print(np.argsort(arr))
# Out:
# [3 1 0 2]

# %% [markdown]
# # Q8. Concatenate Arrays
#
# ## Problem Statement
# Create two arrays:
#
# ```python
# arr1 = [1,2,3]
# arr2 = [4,5,6]
# ```
#
# Concatenate both arrays.
#
# ## Sample Output
# ```python
# [1 2 3 4 5 6]
# ```

# %%
# Write your code here
arr1 =np.array( [1,2,3])
arr2 =np.array ([4,5,6])
print(np.concatenate((arr1,arr2)))
# Out:
# [1 2 3 4 5 6]

# %% [markdown]
# # Q9. Vertical Stacking
#
# ## Problem Statement
# Create two arrays:
#
# ```python
# [1,2,3]
# [4,5,6]
# ```
#
# Combine them using vertical stacking.
#
# ## Sample Output
# ```python
# [[1 2 3]
#  [4 5 6]]
# ```

# %%
# Write your code here
arr1 =np.array( [1,2,3])
arr2 =np.array ([4,5,6])
print(np.vstack((arr1,arr2)))
# Out:
# [[1 2 3]
#  [4 5 6]]

# %% [markdown]
# # Q10. Horizontal Stacking
#
# ## Problem Statement
# Create two arrays:
#
# ```python
# [10,20,30]
# [40,50,60]
# ```
#
# Combine them using horizontal stacking.
#
# ## Sample Output
# ```python
# [10 20 30 40 50 60]
# ```

# %%
# Write your code here
arr1 =np.array( [10,20,30])
arr2 =np.array ([40,50,60])
print(np.hstack((arr1,arr2)))
# Out:
# [10 20 30 40 50 60]
